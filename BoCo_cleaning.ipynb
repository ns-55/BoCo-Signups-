# %%
import pandas as pds
df = pds.read_csv("BoCo_200.csv")

df = df.dropna(subset=['volunteer_id']) # remove rows where volunteer_id = NaN
df['volunteer_id'] = df['volunteer_id'].astype(int).astype(str).str.zfill(3) # convert volunteer_id into numerical entries following same format

mask = df['Referral'] == 'N'
df.loc[mask, 'ref_name'] = 'N/A'

# reformating of csv file entries
for i in range(1, 3):
    event = f"event_date.{i}"
    sign_up = f"sign_up.{i}"
    attend = f"attended.{i}"
    time_in = f"time_in.{i}"
    time_out = f"time_out.{i}"

# formating date entries and naming days of the week for future use
    dt = pds.to_datetime(df[event])
    df[event] = pds.to_datetime(df[event])
    df[event] = dt.dt.strftime("%m/%d/%Y")

    df[f"day_of_week.{i}"] = dt.dt.day_name()

# cleaning up attendance entries
    mask = (df[sign_up] == 'N') & (df[attend].isna())
    df.loc[mask, attend] = 'N/A'

# formating time
for i in range(1, 3):
    time_in = f"time_in.{i}"
    time_out = f"time_out.{i}"

    dt_in = pds.to_datetime(df[time_in], format="%I:%M %p", errors='coerce')
    dt_out = pds.to_datetime(df[time_out], format="%I:%M %p", errors='coerce')
    df[time_in] = dt_in.dt.strftime("%I:%M %p")
    df[time_out] = dt_out.dt.strftime("%I:%M %p")

for i in range(1, 3):
    time_in = f"time_in.{i}"
    time_out = f"time_out.{i}"
    hours = f"hours.{i}"

    df[hours] = (
        pds.to_datetime(df[time_out], format="%I:%M %p", errors='coerce') - pds.to_datetime(df[time_in], format="%I:%M %p", errors='coerce')
    ).dt.total_seconds() / 3600     # seconds -> hrs

    df[hours] = df[hours].fillna(0)

df['total_hours'] = df['hours.1'] + df['hours.2']

mask = (df['total_hours'].isna())
df.loc[mask, 'total_hours'] = 0.0

# cleaning up empty time entries
for i in range(1, 3):
    time_in = f"time_in.{i}"
    time_out = f"time_out.{i}"

    mask = (df[time_in].isna())
    df.loc[mask, [time_in]] = 'N/A'

    mask = (df[time_out].isna())
    df.loc[mask, [time_out]] = 'N/A'

# no case match
df['ref_name'] = df['ref_name'].str.title()

# reorder to keep everything grouped accordingly
new_order = [
    'volunteer_id', 'name_first', 'name_last', 'email', 'phone',
    'Referral', 'ref_name',
    'event_date.1', 'sign_up.1', 'attended.1', 'time_in.1', 'time_out.1', 'day_of_week.1', 'hours.1',
    'event_date.2', 'sign_up.2', 'attended.2', 'time_in.2', 'time_out.2', 'day_of_week.2', 'hours.2',
    'total_hours'
]

df = df[new_order]

df.head(20)
# Out:
#    volunteer_id  name_first    name_last                         email  \
# 0           001       Jane          Doe             jane.doe@gmail.com
# 1           002       John          Doe             john.doe@gmail.com
# 2           003     Emmett     Hutchins      emmett.hutchins@gmail.com
# 3           004       Ezra        Novak           ezra.novak@gmail.com
# 4           005    Camille   Achterberg   camille.achterberg@gmail.com
# 5           006      Silas      Iversen        silas.iversen@gmail.com
# 6           007       Yara    Lindqvist       yara.lindqvist@gmail.com
# 7           008      Anisa   Achterberg     anisa.achterberg@gmail.com
# 8           009      Cyrus   Achterberg     cyrus.achterberg@gmail.com
# 9           010     Rashid      Bianchi       rashid.bianchi@gmail.com
# 10          011  Josephine        Nwosu      josephine.nwosu@gmail.com
# 11          012      Talia     Berglund       talia.berglund@gmail.com
# 12          013     Marcus    Marchetti     marcus.marchetti@gmail.com
# 13          014     Rashid     Fontaine      rashid.fontaine@gmail.com
# 14          015     Bianca     Fontaine      bianca.fontaine@gmail.com
# 15          016   Priyanka     Nakamura    priyanka.nakamura@gmail.com
# 16          017   Priyanka        Novak       priyanka.novak@gmail.com
# 17          018      Cyrus     Berglund       cyrus.berglund@gmail.com
# 18          019      Devon     Bertrand       devon.bertrand@gmail.com
# 19          020      Nadia     Holloway       nadia.holloway@gmail.com
#
#                 phone Referral   ref_name event_date.1 sign_up.1 attended.1  \
# 0   +1 (123) 456-7890        Y  Isabelle    01/01/2027         Y          Y
# 1   +1 (321) 456-7891        N        N/A   01/01/2027         N        N/A
# 2   +1 (225) 959-4506        Y    Adrian    01/01/2027         Y          Y
# 3   +1 (484) 206-2615        N        N/A   01/01/2027         Y          Y
# 4   +1 (500) 843-5925        N        N/A   01/01/2027         Y          Y
# 5   +1 (664) 850-5977        Y  Mireille    01/01/2027         Y          Y
# 6   +1 (434) 232-5168        N        N/A   01/01/2027         Y          N
# 7   +1 (751) 469-9577        N        N/A   01/01/2027         Y          Y
# 8   +1 (211) 896-1876        N        N/A   01/01/2027         Y          Y
# 9   +1 (505) 854-8317        N        N/A   01/01/2027         Y          Y
# 10  +1 (259) 446-9295        N        N/A   01/01/2027         Y          Y
# 11  +1 (752) 973-3295        N        N/A   01/01/2027         Y          Y
# 12  +1 (924) 846-0964        Y     Trent    01/01/2027         N        N/A
# 13  +1 (874) 641-5804        N        N/A   01/01/2027         Y          Y
# 14  +1 (251) 867-8856        N        N/A   01/01/2027         N        N/A
# 15  +1 (588) 202-6396        Y    Quincy    01/01/2027         Y          Y
# 16  +1 (688) 714-8701        Y   Stellan    01/01/2027         Y          Y
# 17  +1 (885) 933-5147        Y   Nikolai    01/01/2027         Y          Y
# 18  +1 (418) 718-4345        Y  Mireille    01/01/2027         N        N/A
# 19  +1 (208) 883-9086        Y     Petra    01/01/2027         N        N/A
#
#     ... day_of_week.1 hours.1 event_date.2  sign_up.2 attended.2 time_in.2  \
# 0   ...        Friday     2.0   01/08/2027          Y          Y  10:00 AM
# 1   ...        Friday     0.0   01/08/2027          Y          N       N/A
# 2   ...        Friday     2.0   01/08/2027          Y          Y  09:00 AM
# 3   ...        Friday     2.0   01/08/2027          Y          Y  10:00 AM
# 4   ...        Friday     2.0   01/08/2027          N        N/A       N/A
# 5   ...        Friday     3.0   01/08/2027          Y          Y  09:30 AM
# 6   ...        Friday     0.0   01/08/2027          Y          Y  09:30 AM
# 7   ...        Friday     3.0   01/08/2027          Y          Y  09:00 AM
# 8   ...        Friday     2.0   01/08/2027          Y          Y  09:00 AM
# 9   ...        Friday     3.0   01/08/2027          N        N/A       N/A
# 10  ...        Friday     3.0   01/08/2027          N        N/A       N/A
# 11  ...        Friday     2.0   01/08/2027          N        N/A       N/A
# 12  ...        Friday     0.0   01/08/2027          Y          Y  10:30 AM
# 13  ...        Friday     2.0   01/08/2027          Y          Y  09:00 AM
# 14  ...        Friday     0.0   01/08/2027          N        N/A       N/A
# 15  ...        Friday     3.0   01/08/2027          Y          Y  10:00 AM
# 16  ...        Friday     2.0   01/08/2027          Y          Y  09:00 AM
# 17  ...        Friday     2.0   01/08/2027          N        N/A       N/A
# 18  ...        Friday     0.0   01/08/2027          N        N/A       N/A
# 19  ...        Friday     0.0   01/08/2027          Y          Y  09:00 AM
#
#    time_out.2 day_of_week.2 hours.2 total_hours
# 0    12:00 PM        Friday     2.0         4.0
# 1         N/A        Friday     0.0         0.0
# 2    11:00 AM        Friday     2.0         4.0
# 3    01:00 PM        Friday     3.0         5.0
# 4         N/A        Friday     0.0         2.0
# 5    11:30 AM        Friday     2.0         5.0
# 6    12:30 PM        Friday     3.0         3.0
# 7    11:00 AM        Friday     2.0         5.0
# 8    12:00 PM        Friday     3.0         5.0
# 9         N/A        Friday     0.0         3.0
# 10        N/A        Friday     0.0         3.0
# 11        N/A        Friday     0.0         2.0
# 12   12:30 PM        Friday     2.0         2.0
# 13   11:00 AM        Friday     2.0         4.0
# 14        N/A        Friday     0.0         0.0
# 15   12:00 PM        Friday     2.0         5.0
# 16   12:00 PM        Friday     3.0         5.0
# 17        N/A        Friday     0.0         2.0
# 18        N/A        Friday     0.0         0.0
# 19   12:00 PM        Friday     3.0         3.0
#
# [20 rows x 22 columns]
